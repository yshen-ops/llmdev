# %%
grades = [85, 90, 78, 92, 88]

print(f"平均点: {sum(grades) / len(grades)}")
print(f"最高点: {max(grades)}")
print(f"最低点: {min(grades)}")
print(f"平均以上の学生数: {len([i for i in grades if i > sum(grades) / len(grades)])}")
# Out:
# 平均点: 86.6
# 最高点: 92
# 最低点: 78
# 平均以上の学生数: 3
