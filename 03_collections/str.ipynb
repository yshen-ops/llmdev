# %%
s = "abcdefghijklmnopqrstuvwxyz"

# 前から
print(s[0]) # a
print(s[1]) # b
print(s[25]) # z

# 後から
print(s[-1]) # z
print(s[-3]) # x
print(s[-26]) # a

print(s[:10]) # 開始位置を省略
print(s[10:]) # 終了位置を省略
print(s[:])   # 両方省略

s = "TechAcademy"
for char in s:
    print(char)
# Out:
# a
# b
# z
# z
# x
# a
# abcdefghij
# klmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# T
# e
# c
# h
# A
# c
# a
# d
# e
# m
# y
