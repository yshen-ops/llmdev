# %%
score = 72  # 成績

match score // 10:
    case 10:
        print("満点です！")
    case 9 | 8:
        print("よくできました！")
    case 7 | 6:
        print("合格です！")
    case _:
        print("不合格です")
# Out:
# 合格です！
