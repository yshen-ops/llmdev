# %%
name = "シンイチュ"
age = 32
print("はじめまして、", name, "と申します。")
print("年齢は", age, "歳です。来年は", age + 1, "歳になります。")
print("よろしくお願いします。")
# Out:
# はじめまして、 シンイチュ と申します。
# 年齢は 32 歳です。来年は 33 歳になります。
# よろしくお願いします。
