# %%
price= int(input("税抜価格を入力してください: "))
tax = int(price/10)
total = price + tax
if total < 2000:
    print("送料は350円です")
    total += 350
else:
    print("送料は無料です")

print(f"送料込税込価格は{total}円です")
# Out:
# 送料は350円です
# 送料込税込価格は498円です
